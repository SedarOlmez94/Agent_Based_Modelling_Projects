# %% [markdown]
# # Urban Observatory Newcastle University
# - Author: Sedar Olmez
# - Data source: http://newcastle.urbanobservatory.ac.uk/
# - Description: Try downloading live sensory data from Newcastle to gain insight on the movement of people across the city. This will then be part of a pipeline system that inputs the data into an agent based model to simulate.

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
import requests
import pandas as pd
import io

# %%
def GeoJSON(data={}, metadata={}):
    bundle = {
            'application/geo+json': data,
            'text/plain': '<IPython.display.GeoJSON object>'
    }
    metadata = {
        'application/geo+json': metadata
    }
    display(bundle, metadata=metadata, raw=True)

# %% [markdown]
# # Retrieve sensor information:

# %%
sensor_params = dict(
    sensor_type = 'Walking North'
)

r = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/csv/',sensor_params)

sensor_info = pd.read_csv(io.StringIO(r.text) )
sensor_info
# Out:
#                                          Sensor Name  \
# 0  PER_PEOPLE_NORTHUMERLAND_LINE_LONG_DISTANCE_HE...
# 1  PER_PEOPLE_NORTHUMERLAND_LINE_LONG_DISTANCE_HE...
# 2  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...
# 3  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...
# 4  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...
# 5  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...
# 6  PER_PEOPLE_NORTHUMERLAND_LINE_MID_DISTANCE_HEAD_0
# 7  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...
# 8  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...
#
#                                Location (WKT)  Ground Height Above Sea Level  \
# 0  POINT (-1.61208941972901 54.9748314715766)                      44.639999
# 1  POINT (-1.61221107799805 54.9748085841739)                      44.549999
# 2  POINT (-1.61149967779594 54.9741066654557)                      43.290001
# 3  POINT (-1.61191367348244 54.9742360249308)                      43.700001
# 4  POINT (-1.61158161684422 54.9742039587214)                      43.480000
# 5  POINT (-1.61177165997381 54.9740544132907)                      43.389999
# 6   POINT (-1.61187546061534 54.974385788398)                      43.849998
# 7  POINT (-1.61182617919363 54.9741458764597)                      43.509998
# 8  POINT (-1.61159110417673 54.9742892668984)                      43.610001
#
#    Sensor Height Above Ground          Broker Name  Third Party  \
# 0                         2.0  People Counting API        False
# 1                         2.0  People Counting API        False
# 2                         2.0  People Counting API        False
# 3                         2.0  People Counting API        False
# 4                         2.0  People Counting API        False
# 5                         2.0  People Counting API        False
# 6                         2.0  People Counting API        False
# 7                         2.0  People Counting API        False
# 8                         2.0  People Counting API        False
#
#    Sensor Centroid Longitude  Sensor Centroid Latitude
# 0                  -1.612089                 54.974831
# 1                  -1.612211                 54.974809
# 2                  -1.611500                 54.974107
# 3                  -1.611914                 54.974236
# 4                  -1.611582                 54.974204
# 5                  -1.611772                 54.974054
# 6                  -1.611875                 54.974386
# 7                  -1.611826                 54.974146
# 8                  -1.611591                 54.974289

# %% [markdown]
# Now that we have all sensors of type Walking North. We can try get the data these sensors capture.

# %%
# Time to plot the sensors on a map.
import smopy
import matplotlib.patheffects as pe

# %%
black_box = (
    min(sensor_info['Sensor Centroid Latitude']),
    min(sensor_info['Sensor Centroid Longitude']),
    max(sensor_info['Sensor Centroid Latitude']),
    max(sensor_info['Sensor Centroid Longitude']),
)

map = smopy.Map(black_box, z = 17)
ax = map.show_mpl(figsize=(15, 15))

for i, row in sensor_info.iterrows():
    x, y = map.to_pixels(row['Sensor Centroid Latitude'], row['Sensor Centroid Longitude'])
    ax.plot(x, y, 'ob', ms = 20, mew = 2);

# %% [markdown]
# # Setting up data parameters

# %%
import datetime

api_date_format = "%Y%m%d%H%M%S"

start_time = datetime.datetime(2019, 9, 17, 0)
end_time = datetime.datetime(2019, 9, 18)

data_parameters = dict(
    data_variable = 'Walking North',
    agg_method = 'median',
    agg_period = '15mins',
    starttime = start_time.strftime(api_date_format),
    endtime = end_time.strftime(api_date_format)
)

data_parameters.update(sensor_params)
data_parameters
# Out:
# {'agg_method': 'median',
#  'agg_period': '15mins',
#  'data_variable': 'Walking North',
#  'endtime': '20190918000000',
#  'sensor_type': 'Walking North',
#  'starttime': '20190917000000'}

# %% [markdown]
# **Get aggregated data**

# %%
r = requests.get('http://uoweb3.ncl.ac.uk/api/v1.1/sensors/data/agg/csv/',data_parameters)
r
# Out:
# <Response [200]>

# %% [markdown]
# **Read the data into a dataframe**

# %%
pedestrian_step_count_data = pd.read_csv(io.StringIO(r.text))
pedestrian_step_count_data.head(10)
# Out:
#                                          Sensor Name       Variable   Units  \
# 0  PER_PEOPLE_NORTHUMERLAND_LINE_LONG_DISTANCE_HE...  Walking North  People
# 1  PER_PEOPLE_NORTHUMERLAND_LINE_MID_DISTANCE_HEAD_0  Walking North  People
# 2  PER_PEOPLE_NORTHUMERLAND_LINE_LONG_DISTANCE_HE...  Walking North  People
# 3  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...  Walking North  People
# 4  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...  Walking North  People
# 5  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...  Walking North  People
# 6  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...  Walking North  People
# 7  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...  Walking North  People
# 8  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...  Walking North  People
# 9  PER_PEOPLE_NORTHUMERLAND_LINE_SHORT_DISTANCE_H...  Walking North  People
#
#              Timestamp  Value  Flagged as Suspect Reading Aggregated Method  \
# 0  2019-09-17 00:00:00    2.0                       False            Median
# 1  2019-09-17 00:00:00   11.0                       False            Median
# 2  2019-09-17 00:00:00    7.5                       False            Median
# 3  2019-09-17 00:00:00    0.0                       False            Median
# 4  2019-09-17 00:00:00    1.0                       False            Median
# 5  2019-09-17 00:00:00    0.5                       False            Median
# 6  2019-09-17 00:00:00    0.0                       False            Median
# 7  2019-09-17 00:00:00    0.0                       False            Median
# 8  2019-09-17 00:00:00    0.0                       False            Median
# 9  2019-09-17 00:15:00    0.0                       False            Median
#
#    Number of records                              Location (WKT)  \
# 0                  2  POINT (-1.61221107799805 54.9748085841739)
# 1                  2   POINT (-1.61187546061534 54.974385788398)
# 2                  2  POINT (-1.61208941972901 54.9748314715766)
# 3                  2  POINT (-1.61149967779594 54.9741066654557)
# 4                  2  POINT (-1.61177165997381 54.9740544132907)
# 5                  2  POINT (-1.61182617919363 54.9741458764597)
# 6                  2  POINT (-1.61159110417673 54.9742892668984)
# 7                  2  POINT (-1.61191367348244 54.9742360249308)
# 8                  2  POINT (-1.61158161684422 54.9742039587214)
# 9                  3  POINT (-1.61177165997381 54.9740544132907)
#
#    Ground Height Above Sea Level  Sensor Height Above Ground  \
# 0                      44.549999                         2.0
# 1                      43.849998                         2.0
# 2                      44.639999                         2.0
# 3                      43.290001                         2.0
# 4                      43.389999                         2.0
# 5                      43.509998                         2.0
# 6                      43.610001                         2.0
# 7                      43.700001                         2.0
# 8                      43.480000                         2.0
# 9                      43.389999                         2.0
#
#            Broker Name  Third Party  Sensor Centroid Longitude  \
# 0  People Counting API        False                  -1.612211
# 1  People Counting API        False                  -1.611875
# 2  People Counting API        False                  -1.612089
# 3  People Counting API        False                  -1.611500
# 4  People Counting API        False                  -1.611772
# 5  People Counting API        False                  -1.611826
# 6  People Counting API        False                  -1.611591
# 7  People Counting API        False                  -1.611914
# 8  People Counting API        False                  -1.611582
# 9  People Counting API        False                  -1.611772
#
#    Sensor Centroid Latitude
# 0                 54.974809
# 1                 54.974386
# 2                 54.974831
# 3                 54.974107
# 4                 54.974054
# 5                 54.974146
# 6                 54.974289
# 7                 54.974236
# 8                 54.974204
# 9                 54.974054

# %% [markdown]
# **Plotting the data**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(30, 10))
for sensor_name, sensor_data in pedestrian_step_count_data.groupby('Sensor Name'):
    
    datetimes = pd.to_datetime(sensor_data['Timestamp'])
    plt.plot(datetimes, sensor_data['Value'], label = sensor_name)

    plt.legend()
